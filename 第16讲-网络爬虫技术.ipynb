# %% [markdown]
# <span id="mulu"><font face="黑体" size=6>本章目录</font></span>
# * [第十六讲 网络爬虫技术]
#     * [16.1 模块要求](#16.1)
#     * [16.2 常规步骤](#16.2)
#     * [16.3 示范](#15.3)
#         * [16.3.1 简单的爬虫demo](#16.3.1)
#         * [16.3.2 豆瓣 —— 查看豆瓣电影数据](#16.3.2)
#         * [16.3.3 知网 —— 查找论文条目](#16.3.3)
#         * [16.3.4 图片抓取](#16.3.4)

# %% [markdown]
# ## 写在前面：
# ### - 课程学习示范，不可用于批量下载，否则责任自负
# ### - 课程学习示范，不可用于批量下载，否则责任自负
# ### - 课程学习示范，不可用于批量下载，否则责任自负
# ## 重要事情说三遍！

# %% [markdown]
# # 第16讲 网络爬虫技术

# %% [markdown]
# ## <font size=5><span id="16.1"> 16.1 模块要求</span></font>

# %% [markdown]
# - urllib —— python 内置（略）:Python自带的一个用于爬虫的库,其主要作用就是可以通过代码模拟浏览器发送请求。
# - requests —— 第三方库（强大）:请求网站获取网页数据的。
# - bs4.BeautifulSoup —— 处理网页数据:灵活又方便的网页解析库,处理高效,支持多种解析器。利用它不用编写正则表达式即可方便地实现网页信息的提取

# %% [markdown]
# - 关于requests
# https://requests.readthedocs.io/en/latest/

# %% [markdown]
# - 关于BeautifulSoup
# https://beautiful-soup-4.readthedocs.io/en/latest/

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## <font size=5><span id="16.2"> 16.2 常规步骤</span></font>

# %% [markdown]
# - 熟悉目标网页
#     - 网址
#     - 内容格式
#     - 编码
#     - 其它
#
#
# - 导入模块 （requests、BeautifulSoup）
#
# - 访问 —— 调用 `requests.get` 函数
#
# - 查询结果代码
#
# - 获取内容并处理

# %% [markdown]
# ## <font size=5><span id="16.3"> 16.3 示范</span></font>

# %% [markdown]
# ### <font size=5><span id="16.3.1"> 16.3.1 简单的爬虫demo</span></font>
# #### 再说一遍：课程学习示范，不可用于批量下载，否则责任自负

# %%
# coding:utf-8

from bs4 import BeautifulSoup
import requests

# 先分析网页代码
url = 'http://python123.io/ws/demo.html'
r = requests.get(url)
demo = r.text  # 服务器返回响应

# %%
demo
# Out:
# '<html><head><title>This is a python demo page</title></head>\r\n<body>\r\n<p class="title"><b>The demo python introduces several python courses.</b></p>\r\n<p class="course">Python is a wonderful general-purpose programming language. You can learn Python from novice to professional by tracking the following courses:\r\n<a href="http://www.icourse163.org/course/BIT-268001" class="py1" id="link1">Basic Python</a> and <a href="http://www.icourse163.org/course/BIT-1001870001" class="py2" id="link2">Advanced Python</a>.</p>\r\n</body></html>'

# %%
soup = BeautifulSoup(demo, "html.parser")
#"""
#demo 表示被解析的html格式的内容
#html.parser表示解析用的解析器
#"""

print(soup.prettify())  # 使用prettify()格式化显示输出
# Out:
# <html>
#  <head>
#   <title>
#    This is a python demo page
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The demo python introduces several python courses.
#    </b>
#   </p>
#   <p class="course">
#    Python is a wonderful general-purpose programming language. You can learn Python from novice to professional by tracking the following courses:
#    <a class="py1" href="http://www.icourse163.org/course/BIT-268001" id="link1">
#     Basic Python
#    </a>
#    and
#    <a class="py2" href="http://www.icourse163.org/course/BIT-1001870001" id="link2">
#     Advanced Python
#    </a>
#    .
#   </p>
#  </body>
# </html>

# %% [markdown]
# - 得到一个BeautifulSoup对象后，一般通过BeautifulSoup类的基本元素来提取html中的内容
#
# <img src = "images\chapter16\1.png" width=800 style="float: left;" />

# %%
print(soup)
# Out:
# <html><head><title>This is a python demo page</title></head>
# <body>
# <p class="title"><b>The demo python introduces several python courses.</b></p>
# <p class="course">Python is a wonderful general-purpose programming language. You can learn Python from novice to professional by tracking the following courses:
# <a class="py1" href="http://www.icourse163.org/course/BIT-268001" id="link1">Basic Python</a> and <a class="py2" href="http://www.icourse163.org/course/BIT-1001870001" id="link2">Advanced Python</a>.</p>
# </body></html>

# %%
print(soup.get_text())
# Out:
# This is a python demo page
#
# The demo python introduces several python courses.
# Python is a wonderful general-purpose programming language. You can learn Python from novice to professional by tracking the following courses:
# Basic Python and Advanced Python.

# %%
print(soup.title)  # 获取html的title标签的信息
print(soup.a)  # 获取html的a标签的信息(soup.a默认获取第一个a标签，想获取全部就用for循环去遍历)
print(soup.a.name)   # 获取a标签的名字
print(soup.a.parent.name)   # a标签的父标签(上一级标签)的名字
print(soup.a.parent.parent.name)  # a标签的父标签的父标签的名字
# Out:
# <title>This is a python demo page</title>
# <a class="py1" href="http://www.icourse163.org/course/BIT-268001" id="link1">Basic Python</a>
# a
# p
# body

# %%
print('a标签类型是：', type(soup.a))   # 查看a标签的类型
print('第一个a标签的属性是：', soup.a.attrs)  # 获取a标签的所有属性(注意到格式是字典)
print('a标签属性的类型是：', type(soup.a.attrs))  # 查看a标签属性的类型
print('a标签的class属性是：', soup.a.attrs['class'])   # 因为是字典，通过字典的方式获取a标签的class属性
print('a标签的href属性是：', soup.a.attrs['href'])   # 同样，通过字典的方式获取a标签的href属性
# Out:
# a标签类型是： <class 'bs4.element.Tag'>
# 第一个a标签的属性是： {'href': 'http://www.icourse163.org/course/BIT-268001', 'class': ['py1'], 'id': 'link1'}
# a标签属性的类型是： <class 'dict'>
# a标签的class属性是： ['py1']
# a标签的href属性是： http://www.icourse163.org/course/BIT-268001

# %% [markdown]
# #### find_all()方法：
#
# 常用通过find_all()方法来查找标签元素：<>.find_all(name, attrs, recursive, string, **kwargs) ，返回一个列表类型，存储查找的结果
#
# • name：对标签名称的检索字符串
# • attrs：对标签属性值的检索字符串，可标注属性检索
# • recursive：是否对子孙全部检索，默认True
# • string：<>…</>中字符串区域的检索字符串

# %%
print('所有a标签的内容：\n', soup.find_all('a')) # 使用find_all()方法通过标签名称查找a标签,返回的是一个列表类型
print("*"*60)
print('a标签和b标签的内容：\n', soup.find_all(['a', 'b']))  # 把a标签和b标签作为一个列表传递，可以一次找到a标签和b标签
# Out:
# 所有a标签的内容：
#  [<a class="py1" href="http://www.icourse163.org/course/BIT-268001" id="link1">Basic Python</a>, <a class="py2" href="http://www.icourse163.org/course/BIT-1001870001" id="link2">Advanced Python</a>]
# ************************************************************
# a标签和b标签的内容：
#  [<b>The demo python introduces several python courses.</b>, <a class="py1" href="http://www.icourse163.org/course/BIT-268001" id="link1">Basic Python</a>, <a class="py2" href="http://www.icourse163.org/course/BIT-1001870001" id="link2">Advanced Python</a>]

# %%
for t in soup.find_all('a'):  # for循环遍历所有a标签，并把返回列表中的内容赋给t
    print('*'*60)
    print('t的值是：', t)  # link得到的是标签对象
    print('t的类型是：', type(t))
    print('a标签中的href属性是：', t.get('href'))  # 获取a标签中的url链接
# Out:
# ************************************************************
# t的值是： <a class="py1" href="http://www.icourse163.org/course/BIT-268001" id="link1">Basic Python</a>
# t的类型是： <class 'bs4.element.Tag'>
# a标签中的href属性是： http://www.icourse163.org/course/BIT-268001
# ************************************************************
# t的值是： <a class="py2" href="http://www.icourse163.org/course/BIT-1001870001" id="link2">Advanced Python</a>
# t的类型是： <class 'bs4.element.Tag'>
# a标签中的href属性是： http://www.icourse163.org/course/BIT-1001870001

# %%
for i in soup.find_all(True):  # 如果给出的标签名称是True，则找到所有标签
    print('标签名称：', i.name)  # 打印标签名称
# Out:
# 标签名称： html
# 标签名称： head
# 标签名称： title
# 标签名称： body
# 标签名称： p
# 标签名称： b
# 标签名称： p
# 标签名称： a
# 标签名称： a

# %%
print('href属性为http..的a标签元素是:', soup.find_all('a', href='http://www.icourse163.org/course/BIT-268001'))  # 标注属性检索
print('class属性为title的标签元素是：', soup.find_all(class_='title'))  # 指定属性，查找class属性为title的标签元素，注意因为class是python的关键字，所以这里需要加个下划线'_'
print('id属性为link1的标签元素是：', soup.find_all(id='link1'))  # 查找id属性为link1的标签元素
# Out:
# href属性为http..的a标签元素是: [<a class="py1" href="http://www.icourse163.org/course/BIT-268001" id="link1">Basic Python</a>]
# class属性为title的标签元素是： [<p class="title"><b>The demo python introduces several python courses.</b></p>]
# id属性为link1的标签元素是： [<a class="py1" href="http://www.icourse163.org/course/BIT-268001" id="link1">Basic Python</a>]

# %%
print(soup.head)  # head标签
print('*'*60)
print(soup.head.contents)   # head标签的儿子标签，contents返回的是列表类型
print('*'*60)
print(soup.body.contents)   # body标签的儿子标签
"""对于一个标签的儿子节点，不仅包括标签节点，也包括字符串节点，比如返回结果中的 \n"""
# Out:
# <head><title>This is a python demo page</title></head>
# ************************************************************
# [<title>This is a python demo page</title>]
# ************************************************************
# ['\n', <p class="title"><b>The demo python introduces several python courses.</b></p>, '\n', <p class="course">Python is a wonderful general-purpose programming language. You can learn Python from novice to professional by tracking the following courses:
# <a class="py1" href="http://www.icourse163.org/course/BIT-268001" id="link1">Basic Python</a> and <a class="py2" href="http://www.icourse163.org/course/BIT-1001870001" id="link2">Advanced Python</a>.</p>, '\n']
# '对于一个标签的儿子节点，不仅包括标签节点，也包括字符串节点，比如返回结果中的 \n'

# %%
print(len(soup.body.contents))  # 获得body标签儿子节点的数量
print(soup.body.contents[1])   # 通过列表索引获取第一个节点的内容

# %%
print(type(soup.body.children))  # children返回的是一个迭代对象，只能通过for循环来使用，不能直接通过索引来读取其中的内容
for i in soup.body.children:   # 通过for循环遍历body标签的儿子节点
    print(i.name)   # 打印节点的名字

# %% [markdown]
# ### <font size=5><span id="16.3.2"> 16.3.2 豆瓣 —— 查看豆瓣电影数据</span></font>

# %% [markdown]
# https://movie.douban.com/top250?start=0&filter=
#
# https://movie.douban.com/top250?start=25&filter=

# %%
# -*- coding: utf-8 -*-

import requests
from bs4 import BeautifulSoup
import time
import random
import re
import pandas as pd
import matplotlib.pyplot as plt

class Douban:
    def __init__(self):
        self.URL = "https://movie.douban.com/top250"
        self.startnum = [i for i in range(0, 251, 25)]
        # 伪装一个浏览器，消息头
        self.header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.111 Safari/537.36'}
    
    def get_top250(self):
        self.number_evaluate = []
        self.score = []
        self.movie_name = []
        for start in self.startnum:
            #print("*"*60)
            time.sleep(random.randint(1,5))  # 伪装成人为随机时间点击
            html = requests.get(self.URL, params = {"start": str(start)}, headers = self.header)
            soup = BeautifulSoup(html.text, "html.parser")

            #content > div > div.article > ol > li > div > div.info > div.hd > a > span:nth-child(1)
            
            # selector copying ,从上到小的
            #content > div > div.article > ol > li:nth-child(1) > div > div.info > div.hd > a > span:nth-child(2)  
            #content > div > div.article > ol > li:nth-child(1) > div > div.info > div.bd > div > span.rating_num
            
            #scores = soup.select('#content > div > div.article > ol > li:nth-child(1) > div > div.info > div.bd > div > span.rating_num')
            #movie_names = soup.select('#content > div > div.article > ol > li:nth-child(1) > div > div.info > div.hd > a > span:nth-child(1)')
            #number_evaluate = soup.select('#content > div > div.article > ol > li:nth-child(1) > div > div.info > div.bd > div > span:nth-child(4)')
            scores = soup.select('#content > div > div.article > ol > li > div > div.info > div.bd > div > span.rating_num')
            movie_names = soup.select('#content > div > div.article > ol > li > div > div.info > div.hd > a > span:nth-child(1)')
            number_evaluate = soup.select('#content > div > div.article > ol > li > div > div.info > div.bd > div > span:nth-child(4)')
            for scorei in scores:
                self.score.append(float(scorei.text))
            
            for movename in movie_names:
                #print(movename)
                self.movie_name.append(movename.text)
            
            for namei in number_evaluate:
                #print(type(namei))
                #print(namei)
                self.number_evaluate.append(int(namei.text[:-3]))
        print(self.number_evaluate)
        print(self.movie_name)
        print(self.score)
        self.result = pd.DataFrame(zip(self.movie_name, self.number_evaluate, self.score))
        # 没有返回结果

    def print_result(self):
        #print('*'*60)
        pd.set_option('display.max_rows', None) # 显示pandas所有行
        return self.result
        #返回一个结果
    pass

if __name__ == '__main__':
    cls = Douban()
    cls.get_top250()
# Out:
# [2890252, 2134320, 2156051, 2184106, 2290812, 2238022, 1323835, 1103336, 1829386, 2055897, 1702779, 1396840, 1674168, 1854991, 1308254, 1313086, 1360066, 1927458, 555692, 1530218, 929319, 965132, 1110196, 1516247, 1263313, 1827967, 881875, 1673290, 841981, 1054229, 1186240, 800368, 689948, 2096684, 1320315, 684736, 1022311, 488840, 1041441, 1565417, 1694456, 870150, 625059, 1020495, 1344865, 609649, 636654, 1218837, 750226, 882020, 948292, 677530, 722992, 1643387, 436185, 835664, 843757, 550986, 837029, 587530, 619203, 843898, 766973, 978765, 562962, 563341, 1109850, 593373, 973385, 1263713, 600185, 1416499, 645098, 827853, 545753, 410023, 886307, 928828, 972301, 934483, 1127845, 853858, 710637, 725698, 356346, 831243, 597036, 630562, 410124, 300179, 967795, 821835, 711790, 940038, 462155, 854949, 753067, 390119, 392254, 1076383, 555652, 702011, 719490, 705211, 1031116, 680445, 664329, 557600, 717314, 554187, 808104, 522565, 1007749, 558463, 594451, 550462, 953062, 551718, 612756, 424363, 944686, 314074, 318218, 735617, 1365056, 667344, 461334, 378502, 567947, 753461, 480112, 373081, 331369, 656712, 537070, 667406, 797384, 513155, 432714, 1195062, 944892, 606672, 420893, 669881, 566890, 258603, 634867, 144502, 1364154, 360718, 644167, 676388, 589370, 336844, 803846, 604517, 780775, 649662, 197331, 609806, 292576, 445706, 1403477, 530741, 817782, 451222, 836247, 519123, 416771, 300757, 539370, 328840, 424278, 353708, 447182, 400726, 328269, 598693, 573152, 818424, 195534, 224593, 442458, 1001822, 132741, 326723, 810290, 585890, 535374, 476443, 976281, 742937, 610396, 858840, 574994, 298756, 458210, 458946, 228830, 331976, 455372, 729528, 776716, 302226, 145804, 831933, 402579, 536353, 667984, 977965, 601667, 443933, 524743, 255907, 340699, 528457, 313319, 403871, 442765, 297472, 253681, 494890, 475322, 549566, 576866, 618150, 290610, 405027, 891778, 378671, 137143, 367414, 366850, 278698, 277580, 571010, 723135, 265804, 351048, 306753, 509037, 473591, 424541, 285833, 564257, 451733, 425309, 655787, 542511, 380391]
# ['肖申克的救赎', '霸王别姬', '阿甘正传', '泰坦尼克号', '这个杀手不太冷', '千与千寻', '美丽人生', '辛德勒的名单', '星际穿越', '盗梦空间', '楚门的世界', '忠犬八公的故事', '海上钢琴师', '三傻大闹宝莱坞', '放牛班的春天', '机器人总动员', '无间道', '疯狂动物城', '控方证人', '大话西游之大圣娶亲', '熔炉', '教父', '触不可及', '当幸福来敲门', '龙猫', '怦然心动', '末代皇帝', '寻梦环游记', '活着', '蝙蝠侠：黑暗骑士', '哈利·波特与魔法石', '指环王3：王者无敌', '乱世佳人', '我不是药神', '飞屋环游记', '素媛', '哈尔的移动城堡', '十二怒汉', '何以为家', '摔跤吧！爸爸', '让子弹飞', '天空之城', '鬼子来了', '猫鼠游戏', '少年派的奇幻漂流', '海蒂和爷爷', '钢琴家', '大话西游之月光宝盒', '指环王2：双塔奇兵', '闻香识女人', '罗马假日', '天堂电影院', '死亡诗社', '绿皮书', '大闹天宫', '黑客帝国', '指环王1：护戒使者', '教父2', '狮子王', '辩护人', '饮食男女', '搏击俱乐部', '美丽心灵', '本杰明·巴顿奇事', '穿条纹睡衣的男孩', '窃听风暴', '情书', '两杆大烟枪', '西西里的美丽传说', '看不见的客人', '音乐之声', '阿凡达', '拯救大兵瑞恩', '哈利·波特与死亡圣器(下)', '飞越疯人院', '小鞋子', '沉默的羔羊', '布达佩斯大饭店', '禁闭岛', '蝴蝶效应', '功夫', '致命魔术', '心灵捕手', '哈利·波特与阿兹卡班的囚徒', '海豚湾', '低俗小说', '超脱', '春光乍泄', '美国往事', '摩登时代', '喜剧之王', '致命ID', '杀人回忆', '七宗罪', '红辣椒', '加勒比海盗', '哈利·波特与密室', '狩猎', '一一', '唐伯虎点秋香', '7号房的礼物', '被嫌弃的松子的一生', '请以你的名字呼唤我', '断背山', '剪刀手爱德华', '爱在黎明破晓前', '入殓师', '勇敢的心', '蝙蝠侠：黑暗骑士崛起', '第六感', '重庆森林', '幽灵公主', '超能陆战队', '爱在日落黄昏时', '菊次郎的夏天', '甜蜜蜜', '天使爱美丽', '借东西的小人阿莉埃蒂', '阳光灿烂的日子', '小森林 夏秋篇', '消失的爱人', '完美的世界', '无人知晓', '倩女幽魂', '寄生虫', '时空恋旅人', '侧耳倾听', '小森林 冬春篇', '幸福终点站', '驯龙高手', '一个叫欧维的男人决定去死', '教父3', '未麻的部屋', '哈利·波特与火焰杯', '萤火之森', '怪兽电力公司', '傲慢与偏见', '玩具总动员3', '新世界', '釜山行', '神偷奶爸', '被解救的姜戈', '玛丽和马克思', '告白', '大鱼', '哪吒闹海', '射雕英雄传之东成西就', '茶馆', '头号玩家', '喜宴', '模仿游戏', '九品芝麻官', '阳光姐妹淘', '我是山姆', '色，戒', '花样年华', '血战钢锯岭', '恐怖直播', '七武士', '头脑特工队', '惊魂记', '黑客帝国3：矩阵革命', '你的名字。', '电锯惊魂', '三块广告牌', '达拉斯买家俱乐部', '疯狂原始人', '心迷宫', '谍影重重3', '上帝之城', '英雄本色', '卢旺达饭店', '纵横四海', '风之谷', '海街日记', '爱在午夜降临前', '绿里奇迹', '记忆碎片', '岁月神偷', '疯狂的石头', '忠犬八公物语', '雨中曲', '荒蛮故事', '小丑', '背靠背，脸对脸', '2001太空漫游', '小偷家族', '爆裂鼓手', '无敌破坏王', '无间道2', '心灵奇旅', '贫民窟的百万富翁', '冰川时代', '恐怖游轮', '东邪西毒', '牯岭街少年杀人事件', '魔女宅急便', '遗愿清单', '东京教父', '你看起来好像很好吃', '大佛普拉斯', '真爱至上', '黑天鹅', '可可西里', '城市之光', '源代码', '雨人', '海边的曼彻斯特', '恋恋笔记本', '初恋这件小事', '波西米亚狂想曲', '人工智能', '青蛇', '虎口脱险', '终结者2：审判日', '疯狂的麦克斯4：狂暴之路', '罗生门', '萤火虫之墓', '新龙门客栈', '千钧一发', '末路狂花', '崖上的波妞', '无耻混蛋', '奇迹男孩', '彗星来的那一夜', '花束般的恋爱', '二十二', '黑客帝国2：重装上阵', '爱乐之城', '血钻', '芙蓉镇', '战争之王', '房间', '步履不停', '魂断蓝桥', '哈利·波特与死亡圣器(上)', '火星救援', '千年女优', '谍影重重2', '弱点', '阿飞正传', '白日梦想家', '谍影重重', '燃情岁月', '哈利·波特与凤凰社', '朗读者', '再次出发之纽约遇见你', '蜘蛛侠：平行宇宙', '香水', '穿越时空的少女']
# [9.7, 9.6, 9.5, 9.5, 9.4, 9.4, 9.6, 9.6, 9.4, 9.4, 9.4, 9.4, 9.3, 9.2, 9.3, 9.3, 9.3, 9.2, 9.6, 9.2, 9.4, 9.3, 9.3, 9.2, 9.2, 9.1, 9.3, 9.1, 9.3, 9.2, 9.2, 9.3, 9.3, 9.0, 9.1, 9.3, 9.1, 9.4, 9.1, 9.0, 9.0, 9.2, 9.3, 9.1, 9.1, 9.3, 9.3, 9.0, 9.2, 9.1, 9.1, 9.2, 9.2, 8.9, 9.4, 9.1, 9.1, 9.3, 9.1, 9.2, 9.2, 9.0, 9.1, 9.0, 9.2, 9.2, 8.9, 9.1, 8.9, 8.8, 9.1, 8.8, 9.1, 9.0, 9.1, 9.2, 8.9, 8.9, 8.9, 8.9, 8.8, 8.9, 8.9, 8.9, 9.3, 8.9, 9.0, 9.0, 9.2, 9.3, 8.8, 8.9, 8.9, 8.8, 9.1, 8.8, 8.9, 9.1, 9.1, 8.7, 8.9, 8.9, 8.9, 8.8, 8.7, 8.8, 8.9, 8.9, 8.8, 8.9, 8.8, 8.9, 8.7, 8.9, 8.9, 8.9, 8.7, 8.9, 8.9, 9.0, 8.7, 9.1, 9.1, 8.8, 8.8, 8.8, 8.9, 9.0, 8.8, 8.8, 8.9, 9.0, 9.1, 8.8, 8.9, 8.8, 8.7, 8.9, 8.9, 8.6, 8.7, 8.8, 9.0, 8.8, 8.8, 9.2, 8.7, 9.6, 8.7, 9.0, 8.8, 8.7, 8.8, 9.0, 8.7, 8.7, 8.7, 8.7, 9.3, 8.8, 9.0, 8.8, 8.5, 8.8, 8.7, 8.8, 8.7, 8.7, 8.8, 9.0, 8.6, 8.9, 8.8, 8.9, 8.8, 8.9, 8.9, 8.7, 8.7, 8.6, 9.2, 9.1, 8.8, 8.7, 9.5, 8.9, 8.7, 8.7, 8.7, 8.7, 8.7, 8.6, 8.6, 8.5, 8.6, 8.9, 8.7, 8.7, 9.0, 8.9, 8.7, 8.6, 8.6, 8.9, 9.3, 8.5, 8.7, 8.6, 8.5, 8.5, 8.6, 8.7, 8.6, 8.9, 8.8, 8.7, 8.8, 8.7, 8.7, 8.8, 8.9, 8.6, 8.6, 8.6, 8.6, 8.6, 8.7, 8.7, 8.4, 8.7, 9.3, 8.7, 8.8, 8.8, 8.8, 8.5, 8.5, 8.8, 8.7, 8.7, 8.5, 8.6, 8.6, 8.8, 8.5, 8.6, 8.6, 8.6, 8.5, 8.6]

# %%
result = cls.print_result()
result.columns = ["影片名称", "评价人数", "评分"]
result

# %%
import matplotlib.pyplot as plt
plt.plot(result["评价人数"], result["评分"],'.')
plt.xlabel("Evaluate Persons")
plt.ylabel("Score")

# %% [markdown]
# - get请求使用了headers参数，这个是用来模拟浏览器的。
# - 如何知道‘User-Agent’是什么呢？

# %% [markdown]
# ### <font size=5><span id="16.3.3"> 16.3.3 知网 —— 查找论文条目</span></font>

# %% [markdown]
# - 关注机器学习与大数据方面的最新研究动向
# - 关键词组
#     - 机器学习
#     - 大数据

# %%
url = "http://search.cnki.com.cn/Search/Result?content=机器学习 大数据"

# %%
#sleeptime=random.randint(0, 180)    # 随机等待一段时间
#time.sleep(sleeptime)

print("OK!")

response_string = requests.get(url)
response_string
# Out:
# OK!
# <Response [200]>

# %%
content = BeautifulSoup(response_string.content.decode("utf-8"), 'html.parser')  # "lxml" -> 'html.parser'

# %%
print(content.text)
# Out:
# ﻿
#
#
#
#
#
#
#
# 综合搜索_知网空间
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 搜索
#
#
# 智能排版 >>个人查重 >>
#
#
#
#
#
#
#
#
#
#
#  全  文
#
#
#
#
#
#
#
# 从
#
# 不  限
#
#
#
# 不  限
# 1915年
# 1949年
# 1979年
#
#
#
# 到
#
# 不  限
#
#
#
# 不  限
# 1979年
# 1949年
# 1915年
#
#
#
#
# 全  文
# 主  题
# 篇  名
# 关键词
# 作  者
# 作者单位
# 摘  要
# 参考文献
# 基  金
# 文献来源
# 发表时间
# 中图分类号
#
#
#
# 搜索
# 快捷搜索
#
#
#
#
#
#
#
#
#
#
#
#
#
# 全  文
#
#
#
#
#
#
#
# 从不  限
#
# 不  限
# 1915年
# 1949年
# 1979年
#
#
#
# 到不  限
#
# 不  限
# 1979年
# 1949年
# 1915年
#
#
#
#
# 全  文
# 主  题
# 篇  名
# 关键词
# 作  者
# 作者单位
# 摘  要
# 参考文献
# 基  金
# 文献来源
# 发表时间
# 中图分类号
#
#
#
# 搜索
# 快捷搜索
#
#
#
#
#
#
# 设置
#
#
# 关闭历史记录
# 打开历史纪录
# 清除历史记录
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 引用
#
#
#
# 筛选：
#
# 文献类型
# 文献类型
#
#
#
# 学科分类
# 学科分类
#
#
#
# 发表年度
# 发表年度
#
#
#
# 作者
# 作者
#
#
#
# 机构
# 机构
#
#
#
# 基金
# 基金
#
#
#
# 研究层次
# 研究层次
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 已选：
#
#
# 排序：
#
# 按相关度排序
#
# 按相关度排序
# 按发表时间排序
# 按下载次数排序
# 按被引次数排序
#
#
#
#
# 显示：
#
#
#
# CNKI为你找到相关结果条
#
#
#
#
#
#
#
#
#
#
#
#
#
# 基于多维动态大数据的新兴产业技术预测分析方法  CNKI文献
#
#
# [目的/意义]探讨相关多维动态大数据特征以及在新兴产业技术预测分析中的作用，从而整合多维动态大数据信息知识，为新兴产业技术预测分析提供框架支持。[方法/过程]首先通过探究分析专利大数据、论...
#
#
# 徐璐
# 潘禹辰
#
#
# 《情报资料工作》
#
#
# 2023年04期
#
# 期刊
#
#
#
#                     关键词：
#                     新兴产业技术
#                         /
#                     多维动态大数据
#                         /
#                     关联模式架构
#                         /
#                     新兴指数
#
# 下载（0）| 被引（0）
#
#
#
#
#
#
# 智能管道大数据总体设计及几个关键技术探讨  CNKI文献
#
#
# 随着油气管道建设步伐不断加快，基于大数据、物联网、人工智能等先进技术的智能管道建设成为新趋势和新热点，其中大数据是智能管道建设领域的重点研究内容。首先，针对智能管道大数据的特点以及面...
#
#
# 张玉媛
# 郭新然...
#
#
# 《物联网技术》
#
#
# 2023年07期
#
# 期刊
#
#
#
#                     关键词：
#                     智能管道
#                         /
#                     大数据
#                         /
#                     物联网
#                         /
#                     AI
#
# 下载（12）| 被引（0）
#
#
#
#
#
#
# 机器学习在植物工厂中的研究现状与挑战  CNKI文献
#
#
# 为有效缓解来自人口、环境和资源方面的压力，发展植物工厂非常重要。智慧植物工厂是设施农业发展的高级阶段，研究如何将机器学习应用在植物工厂中有效提高生产效率，促使植物工厂向智能化方向发展是一个重要的...
#
#
# 孙博
# 李靖...
#
#
# 《中国农学通报》
#
#
# 2023年18期
#
# 期刊
#
#
#
#                     关键词：
#                     机器学习
#                         /
#                     植物工厂
#                         /
#                     研究
#                         /
#                     现状
#
# 下载（90）| 被引（0）
#
#
#
#
#
#
# 高等教育数字化转型的现实困境与突破路径  CNKI文献
#
#
# 随着大数据、机器学习和人工智能等新一代数字技术的快速发展和广泛应用,高等教育数字化转型已成为一项全球性议题。在明确高等教育数字化转型内在意蕴和基本特征的基础上,通过研究发现其在实践中存在着教...
#
#
# 刘锦毓
# 赵智兴
#
#
# 《成都航空职业技术学院学报》
#
#
# 2023年02期
#
# 期刊
#
#
#
#                     关键词：
#                     高等教育
#                         /
#                     数字化转型
#                         /
#                     内在意蕴
#                         /
#                     现实困境
#
# 下载（103）| 被引（0）
#
#
#
#
#
#
#
# 美国国家工程院院士、东方理工高等研究院常务副院长兼教务...  CNKI文献
#
#
# 机器学习模型预测原理是利用大量历史数据，寻找并确定输入多元变量与目标变量的复杂映射关系，构造模型并基于该模型对未来的目标变量进行预测。常用机器学习模型有人工神经网络、支持向量机、卷积神经网...
#
#
# 高艳飞
#
#
# 《当代贵州》
#
#
# 2023年23期
#
# 期刊
#
#
#
#                     关键词：
#                     知识嵌入
#                         /
#                     人工智能
#                         /
#                     国家工程院
#                         /
#                     知识发现
#
# 下载（9）| 被引（0）
#
#
#
#
#
#
# 融合外部注意力机制的基金业绩预测方法及其应用研究  CNKI文献
#
#
# 证券投资基金在我国的资本市场中发挥重要的作用,基金的发展也保证了市场的完善性与平稳性,并为投资者提供了更多的投资选择。在基金行业快速发展的今天,随着基金规模不断的扩大,基金作为一种重要的商品在资本市场上受...
#
#
# 潘宇庭
#
# 导师:周伟
# 云南财经大学
# 2023-05-30
# 硕士论文
#
#
#
#                     关键词：
#                     机器学习
#                         /
#                     基金业绩
#                         /
#                     注意力机制
#                         /
#                     边际贡献
#
# 下载（14）| 被引（0）
#
#
#
#
#
#
# 基于大数据技术的银行业务分析  CNKI文献
#
#
# 在当下数据化的时代，银行商业模式也在随时代变化，大数据与机器学习技术被广泛运用于信贷、负债与审计业务中。本文基于信息检索的方式，介绍了大数据技术在商业银行中的主要应用。具体来说，本文...
#
#
# 贺一珉
#
#
# 《现代商业》
#
#
# 2023年10期
#
# 期刊
#
#
#
#                     关键词：
#                     大数据分析
#                         /
#                     银行业务
#                         /
#                     用户画像
#
# 下载（99）| 被引（0）
#
#
#
#
#
#
# 大数据赋能高校思想政治工作精准化研究  CNKI文献
#
#
# 高校作为我国思想政治工作的主战场,围绕立德树人的根本任务,始终在不断创新育人模式。当前,随着现代化信息技术的迅猛发展,人类已经进入了海量数据挖掘、分析与应用的“大数据时代”。高速发展的数据技术使得高...
#
#
# 陈惠敏
#
# 导师:吴跃东
# 上海师范大学
# 2023-05-28
# 硕士论文
#
#
#
#                     关键词：
#                     大数据
#                         /
#                     高校思想政治工作
#                         /
#                     精准化
#
# 下载（228）| 被引（0）
#
#
#
#
#
#
# 基于机器学习的上市公司财务舞弊识别研究  CNKI文献
#
#
# 我国上市公司财务舞弊行为层出不穷,舞弊手法呈现出隐蔽化、复杂化的特点。如何有效识别和揭示上市公司财务舞弊行为,对资本市场的健康发展具有重要意义。大数据技术的发展为处理海量数据、提取有价值的信息提供...
#
#
# 罗娜
#
# 导师:朱锦余
# 云南财经大学
# 2023-05-26
# 硕士论文
#
#
#
#                     关键词：
#                     财务舞弊
#                         /
#                     机器学习
#                         /
#                     财务舞弊识别
#                         /
#                     制造业
#
# 下载（138）| 被引（0）
#
#
#
#
#
#
# 基于机器学习的新型高强镍基高温合金设计与优化  CNKI文献
#
#
# 先进航空发动机材料是国家航空事业发展的关键。镍基高温合金因具有高强度、抗蠕变、抗疲劳和耐腐蚀的优异综合性能,成为航空发动机高温结构部件的关键材料。高推重比航空发动机的发展需要高性能镍基高温合金作为支持...
#
#
# 徐斌
#
# 导师:尹海清
# 北京科技大学
# 2023-05-26
# 博士论文
#
#
#
#                     关键词：
#                     镍基高温合金
#                         /
#                     机器学习
#                         /
#                     热力学计算
#                         /
#                     沉淀强化
#
# 下载（165）| 被引（0）
#
#
#
#
#
#
# 光纤激光网络故障大数据自动分类方法  CNKI文献
#
#
# 光纤激光网络通信受噪声影响，导分类效果较差，提出了光纤激光网络故障大数据自动分类方法。对数据进行噪处理，将源域中的样本和目标领域的样本配对处理，采用非线性变换提供故障特征，通过K-means算法和最近...
#
#
# 汪滢
# 熊璐...
#
#
# 《激光杂志》
#
#
# 2023年05期
#
# 期刊
#
#
#
#                     关键词：
#                     光纤激光网络
#                         /
#                     故障大数据
#                         /
#                     自动分类
#                         /
#                     K-means算法
#
# 下载（15）| 被引（0）
#
#
#
#
#
#
# 大数据环境下机器学习课程的教学实践探索  CNKI文献
#
#
# 结合大数据应用的时代背景,高校教学科研的重心也随之发生变化。机器学习课程作为数据科学与大数据技术专业的专业核心课,依托于现阶段计算机技术的更新迭代,涉及多学科的交叉学科课程,兼顾理论与实...
#
#
# 杜科君
#
#
# 《互联网周刊》
#
#
# 2023年10期
#
# 期刊
#
#
#
#                     关键词：
#                     机器学习
#                         /
#                     大数据
#                         /
#                     教学研究
#
# 下载（268）| 被引（0）
#
#
#
#
#
#
# 大数据背景下机器学习在体育领域的应用和展望  CNKI文献
#
#
# 研究目的:在大数据时代,伴随着互联网、物联网等技术的高速发展致使海量结构化和半结构化数据产生,从而导致体育领域的数据量也呈现指数上升的趋势。目前,体育已经成为一个信息多元、数据丰富的领域,我们正处于非常重...
#
#
# 江礼磊
# 黄谦
#
# 2023年第十一届全国体育管理科学大会论文摘要集
# 2023-05-20
# 中国会议
#
#
#
#                     关键词：
#                     机器学习
#                         /
#                     学校体育
#                         /
#                     群众体育
#                         /
#                     竞技体育
#
# 下载（17）| 被引（0）
#
#
#
#
#
#
# 基于大数据的卫星遥测数据故障征兆分析方法  CNKI文献
#
#
# 卫星在轨遥测数据信息量巨大，且表征卫星在轨道上的运行状态和故障趋势[1]。首先，介绍了大数据在卫星故障分析方面的研究现状；其次，在现有研究的基础上充分地运用大数据技术，解决卫星遥测大数据
#
#
# 曹宇
# 韩邢健
#
#
# 《电子质量》
#
#
# 2023年05期
#
# 期刊
#
#
#
#                     关键词：
#                     大数据
#                         /
#                     卫星遥测数据
#                         /
#                     故障征兆
#
# 下载（26）| 被引（0）
#
#
#
#
#
#
# 旅游大数据赋能的游客出游预测模型研究  CNKI文献
#
#
# 旅游客流量的及时性和准确性分析是我国智慧旅游建设的一个重要研究问题。旅游客流量分析有助于旅游管理相关部门对旅游活动进行有效管理,同时有助于旅游当地的餐饮、住宿、出行、游玩、购物、娱乐等方面的建设和发展...
#
#
# 何靖
#
# 导师:王静
# 云南财经大学
# 2023-05-18
# 硕士论文
#
#
#
#                     关键词：
#                     旅游客流量
#                         /
#                     大理
#                         /
#                     百度搜索指数
#                         /
#                     机器学习模型
#
# 下载（55）| 被引（0）
#
#
#
#
#
#
# 机器学习在市场营销领域的应用探索  CNKI文献
#
#
# 随着网络购物、移动支付、社交电商的发展，市场营销过程中产生的数据特征和数据结构出现了翻天覆地的变化，大数据时代已经到来，机器学习也成为更有效的大数据处理方法。机器学习可以帮助构...
#
#
# 杨艺敏
#
#
# 《商业经济》
#
#
# 2023年06期
#
# 期刊
#
#
#
#                     关键词：
#                     市场营销
#                         /
#                     机器学习
#
# 下载（757）| 被引（0）
#
#
#
#
#
#
# 科学发现中的机器学习方法研究  CNKI文献
#
#
# 大规模科学装置与重大科学实验使得科学发现进入了数据密集型的第四范式,借助蓬勃发展的人工智能技术促进智能科学发现势在必行.机器学习作为人工智能中的一项重要技术,已广泛应用于各个科学领域.然而,现有工作...
#
#
# 孟小峰
# 郝新丽...
#
#
# 《计算机学报》
#
#
# 2023年05期
#
# 期刊
#
#
#
#                     关键词：
#                     科学发现
#                         /
#                     机器学习
#                         /
#                     科学大数据
#                         /
#                     瞬变事件发现
#
# 下载（821）| 被引（0）
#
#
#
#
#
#
# “大数据技术导论”课程改革研究  CNKI文献
#
#
# “大数据技术导论”课程作为大数据相关专业的入门课程或基础性课程，对持续学习相关专业知识和培养兴趣有重要作用。但是该课程存在授课方式单一、学习资源有限、评价方式简单等问题。为此，需要在课程设...
#
#
# 廖雅婕
#
#
# 《韶关学院学报》
#
#
# 2023年05期
#
# 期刊
#
#
#
#                     关键词：
#                     大数据技术导论
#                         /
#                     机器学习
#                         /
#                     课程教学改革
#
# 下载（12）| 被引（0）
#
#
#
#
#
#
# 论新一代法律智能系统的融合性道路  CNKI文献
#
#
# 新一代法律智能系统呈现出符号主义与联结主义法律人工智能相融合的趋势。以生成式人工智能ChatGPT为代表的智能系统由大数据驱动，采用机器学习算法挖掘法律文本大数据，在类案检索、判决预测、法...
#
#
# 魏斌
#
#
# 《法学论坛》
#
#
# 2023年03期
#
# 期刊
#
#
#
#                     关键词：
#                     法律智能系统
#                         /
#                     法律逻辑学
#                         /
#                     法律大数据
#                         /
#                     ChatGPT
#
# 下载（416）| 被引（0）
#
#
#
#
#
#
# 大数据背景下的智能型自适应在线学习行为研究  CNKI文献
#
#
# 随着大数据和人工智能技术的快速发展，智能型自适应在线学习作为一种新型学习模式受到了越来越多人的关注。通过对智能型自适应在线学习的概念、分类、方法、应用场景和未来趋势进行研究，旨在为读者提供一份较...
#
#
# 刘莹
# 杨淑萍
#
#
# 《继续教育研究》
#
#
# 2023年06期
#
# 期刊
#
#
#
#                     关键词：
#                     大数据
#                         /
#                     智能型自适应
#                         /
#                     在线学习
#                         /
#                     学习行为
#
# 下载（464）| 被引（0）
#
#
#
#
#
#
#
#
# 题   名
# 作者
# 来   源
# 发表时间
# 类型
# 被引
# 下载
# 操作
#
#
#
# 1
#
#
#
#
#
# 基于多维动态大数据的新兴产业技术预测分析方法
#
#
#
#
# 徐璐
# 潘禹辰
#
#
#
#
# 《情报资料工作》
#
#
#
#
#                     2023-07-17
#
#
# 期刊
# 0
# 0
#
#
#
#
#
#
# 2
#
#
#
#
#
# 智能管道大数据总体设计及几个关键技术探讨
#
#
#
#
# 张玉媛
# 郭新然
#
#
#
#
# 《物联网技术》
#
#
#
#
#                     2023-07-13
#
#
# 期刊
# 0
# 12
#
#
#
#
#
#
# 3
#
#
#
#
#
# 机器学习在植物工厂中的研究现状与挑战
#
#
#
#
# 孙博
# 李靖
#
#
#
#
# 《中国农学通报》
#
#
#
#
#                     2023-06-25
#
#
# 期刊
# 0
# 90
#
#
#
#
#
#
# 4
#
#
#
#
#
# 高等教育数字化转型的现实困境与突破路径
#
#
#
#
# 刘锦毓
# 赵智兴
#
#
#
#
# 《成都航空职业技术学院...》
#
#
#
#
#                     2023-06-19
#
#
# 期刊
# 0
# 103
#
#
#
#
#
#
# 5
#
#
#
#
#
# 美国国家工程院院士、东方理工高等研究院常务副院长兼教务长张东晓：知...
#
#
#
#
# 高艳飞
#
#
#
#
# 《当代贵州》
#
#
#
#
#                     2023-06-01
#
#
# 期刊
# 0
# 9
#
#
#
#
#
#
# 6
#
#
#
#
#
# 融合外部注意力机制的基金业绩预测方法及其应用研究
#
#
#
#
# 潘宇庭
#
#
#
#
# 云南财经大学
#
#
#
#
#                     2023-05-30
#
#
# 硕士
# 0
# 14
#
#
#
#
#
#
# 7
#
#
#
#
#
# 基于大数据技术的银行业务分析
#
#
#
#
# 贺一珉
#
#
#
#
# 《现代商业》
#
#
#
#
#                     2023-05-28
#
#
# 期刊
# 0
# 99
#
#
#
#
#
#
# 8
#
#
#
#
#
# 大数据赋能高校思想政治工作精准化研究
#
#
#
#
# 陈惠敏
#
#
#
#
# 上海师范大学
#
#
#
#
#                     2023-05-28
#
#
# 硕士
# 0
# 228
#
#
#
#
#
#
# 9
#
#
#
#
#
# 基于机器学习的上市公司财务舞弊识别研究
#
#
#
#
# 罗娜
#
#
#
#
# 云南财经大学
#
#
#
#
#                     2023-05-26
#
#
# 硕士
# 0
# 138
#
#
#
#
#
#
# 10
#
#
#
#
#
# 基于机器学习的新型高强镍基高温合金设计与优化
#
#
#
#
# 徐斌
#
#
#
#
# 北京科技大学
#
#
#
#
#                     2023-05-26
#
#
# 博士
# 0
# 165
#
#
#
#
#
#
# 11
#
#
#
#
#
# 光纤激光网络故障大数据自动分类方法
#
#
#
#
# 汪滢
# 熊璐
#
#
#
#
# 《激光杂志》
#
#
#
#
#                     2023-05-25
#
#
# 期刊
# 0
# 15
#
#
#
#
#
#
# 12
#
#
#
#
#
# 大数据环境下机器学习课程的教学实践探索
#
#
#
#
# 杜科君
#
#
#
#
# 《互联网周刊》
#
#
#
#
#                     2023-05-20
#
#
# 期刊
# 0
# 268
#
#
#
#
#
#
# 13
#
#
#
#
#
# 大数据背景下机器学习在体育领域的应用和展望
#
#
#
#
# 江礼磊
# 黄谦
#
#
#
#
# 2023年第十一届全国体...
#
#
#
#
#                     2023-05-20
#
#
# 会议
# 0
# 17
#
#
#
#
#
#
# 14
#
#
#
#
#
# 基于大数据的卫星遥测数据故障征兆分析方法
#
#
#
#
# 曹宇
# 韩邢健
#
#
#
#
# 《电子质量》
#
#
#
#
#                     2023-05-20
#
#
# 期刊
# 0
# 26
#
#
#
#
#
#
# 15
#
#
#
#
#
# 旅游大数据赋能的游客出游预测模型研究
#
#
#
#
# 何靖
#
#
#
#
# 云南财经大学
#
#
#
#
#                     2023-05-18
#
#
# 硕士
# 0
# 55
#
#
#
#
#
#
# 16
#
#
#
#
#
# 机器学习在市场营销领域的应用探索
#
#
#
#
# 杨艺敏
#
#
#
#
# 《商业经济》
#
#
#
#
#                     2023-05-17
#
#
# 期刊
# 0
# 757
#
#
#
#
#
#
# 17
#
#
#
#
#
# 科学发现中的机器学习方法研究
#
#
#
#
# 孟小峰
# 郝新丽
#
#
#
#
# 《计算机学报》
#
#
#
#
#                     2023-05-15
#
#
# 期刊
# 0
# 821
#
#
#
#
#
#
# 18
#
#
#
#
#
# “大数据技术导论”课程改革研究
#
#
#
#
# 廖雅婕
#
#
#
#
# 《韶关学院学报》
#
#
#
#
#                     2023-05-15
#
#
# 期刊
# 0
# 12
#
#
#
#
#
#
# 19
#
#
#
#
#
# 论新一代法律智能系统的融合性道路
#
#
#
#
# 魏斌
#
#
#
#
# 《法学论坛》
#
#
#
#
#                     2023-05-10
#
#
# 期刊
# 0
# 416
#
#
#
#
#
#
# 20
#
#
#
#
#
# 大数据背景下的智能型自适应在线学习行为研究
#
#
#
#
# 刘莹
# 杨淑萍
#
#
#
#
# 《继续教育研究》
#
#
#
#
#                     2023-05-08
#
#
# 期刊
# 0
# 464
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 学术研究指数分析(近十年)详情>>
#
#
#
# 发文趋势
#
#
#
#
#
#
#
#
#
#
# 学术研究指数分析
# 机器学习 大数据
#
#
#
#
#
#
# 发文趋势
#
#
# From
#
#
#
# To
#
#
#
# 查询
#
#
#
#
#
#
#
#
#
#
#
# 题名(按相关度排序,默认前十条)
# 作者
# 年/期
# 下载
# 被引
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 全选
# 全部清除
# 已选文献（0）
# 生成参考文献
#
#
#
#
#
#
#
# 关于CNKI|
#             用户反馈
#                  © 2016-2023 《中国学术期刊（光盘版）》电子杂志社有限公司 京ICP证040431号 网络出版服务许可证 (总)网出证(京)字第 271 号 京公网安备 11010802020460 号
#
#
#
#
# 用户反馈
#
#
#
#
#
#
#
#
#
#
#
# 用户反馈

# %%
records_titles = content.select('#article_result > div > div > p.tit.clearfix > a:nth-child(2)')
# #article_result > div > div:nth-child(1) > p.tit.clearfix > a:nth-child(2)
records_authors = content.select('#article_result > div > div > p.source > span:nth-child(1)')
# #article_result > div > div:nth-child(1) > p.source > span:nth-child(1)
records_journal = content.select('#article_result > div > div > p.source > a:nth-child(2) > span')
records_date = content.select('#article_result > div > div > p.source > a:nth-child(3) > span')

titles, authors, journal, date = [], [], [], []
for each in records_date:
    date.append(each.text)

for each in records_journal:
    journal.append(each["title"])

for each in records_authors:
    authors.append(each["title"])
    
for each in records_titles:
    titles.append(each["title"])

for t,a,j,d in zip(titles, authors, journal, date):
    print(t,", ",a,", ",j,", ",d)
# Out:
# 基于多维动态大数据的新兴产业技术预测分析方法 ,  徐璐;潘禹辰 ,  情报资料工作 ,  2023年04期
# 智能管道大数据总体设计及几个关键技术探讨 ,  张玉媛;郭新然;周云奕;蔡康健;石坤 ,  物联网技术 ,  2023年07期
# 机器学习在植物工厂中的研究现状与挑战 ,  孙博;李靖;王静 ,  中国农学通报 ,  2023年18期
# 高等教育数字化转型的现实困境与突破路径 ,  刘锦毓;赵智兴 ,  成都航空职业技术学院学报 ,  2023年02期
# 美国国家工程院院士、东方理工高等研究院常务副院长兼教务长张东晓：知识嵌入和知识发现在人工智能中同样重要 ,  高艳飞 ,  当代贵州 ,  2023年23期
# 融合外部注意力机制的基金业绩预测方法及其应用研究 ,  潘宇庭 ,  现代商业 ,  2023年10期
# 基于大数据技术的银行业务分析 ,  贺一珉 ,  激光杂志 ,  2023年05期
# 大数据赋能高校思想政治工作精准化研究 ,  陈惠敏 ,  互联网周刊 ,  2023年10期
# 基于机器学习的上市公司财务舞弊识别研究 ,  罗娜 ,  电子质量 ,  2023年05期
# 基于机器学习的新型高强镍基高温合金设计与优化 ,  徐斌 ,  商业经济 ,  2023年06期
# 光纤激光网络故障大数据自动分类方法 ,  汪滢;熊璐;刘晓 ,  计算机学报 ,  2023年05期
# 大数据环境下机器学习课程的教学实践探索 ,  杜科君 ,  韶关学院学报 ,  2023年05期
# 大数据背景下机器学习在体育领域的应用和展望 ,  江礼磊;黄谦 ,  法学论坛 ,  2023年03期
# 基于大数据的卫星遥测数据故障征兆分析方法 ,  曹宇;韩邢健 ,  继续教育研究 ,  2023年06期

# %% [markdown]
# ### <font size=5><span id="16.3.4"> 16.3.4 图片抓取</span></font>

# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import random

# %% [markdown]
# #### （1）先分析，从小做起

# %%
# 单张图片获取，获取链接，直接下载
response = requests.get(url="https://pic.netbian.com/4kfengjing/index_11.html")
response.encoding = 'ANSI'  #没有这句，看到的乱码
html = response.text
soup = BeautifulSoup(html, 'html.parser')
allli = soup.find_all('li') #获取标签为li的所有结果，存成列表
allli
#看看是啥？

begin = "https://pic.netbian.com"
src="/uploads/allimg/211109/221532-1636467332536d.jpg"
wuhu = requests.get(url=begin+src)
wuhu

where = r'web_spider/pic/test.jpg' #% (m)#这个m在main函数开头定义了
f = open(where, 'wb')
f.write(wuhu.content)
time.sleep(3)#每下载一张图片等3秒，当然为了速度你也不用要这一行
# 查看图片，太小了
# 不是太满意

# %%
# 单张图片获取，获取链接，直接下载，此次根据链接，打开大图
response = requests.get(url="https://pic.netbian.com/tupian/28265.html")
response.encoding = 'ANSI'  #没有这句，看到的乱码
html = response.text
soup = BeautifulSoup(html, 'html.parser')
alldiv = soup.find_all('div', class_='photo-pic')
alldiv
#看看是啥？
begin = "https://pic.netbian.com"
src="/uploads/allimg/211109/221532-163646733295cd.jpg"
wuhu = requests.get(url=begin+src)
wuhu
where = r'web_spider/pic/test-big.jpg' #% (m)#这个m在main函数开头定义了
f = open(where, 'wb')
f.write(wuhu.content)
time.sleep(3)#每下载一张图片等3秒，当然为了速度你也不用要这一行
# 基本满意

# %% [markdown]
# #### （2）伪装

# %%
baseurl='http://pic.netbian.com/4kfengjing/'
ualist = ["Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:23.0) Gecko/20131011 Firefox/23.0",
    "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/27.0.1453.90 Safari/537.36",
    "Mozilla/5.0 (Windows NT 10.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/40.0.2214.93 Safari/537.36",
    "Mozilla/5.0 (X11; Linux i586; rv:31.0) Gecko/20100101 Firefox/31.0",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/31.0.1623.0 Safari/537.36",
    "Mozilla/5.0 (Windows; U; Windows NT 6.0; nb-NO) AppleWebKit/533.18.1 (KHTML, like Gecko) Version/5.0.2 Safari/533.18.5",
    "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.67 Safari/537.36",
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2227.1 Safari/537.36",
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36",
    "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.14 (KHTML, like Gecko) Chrome/24.0.1292.0 Safari/537.14",
    "Mozilla/5.0 (Windows NT 4.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2049.0 Safari/537.36",
    "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/28.0.1464.0 Safari/537.36",
    "Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; WOW64; Trident/5.0; SLCC2; Media Center PC 6.0; InfoPath.3; MS-RTC LM 8; Zune 4.7)",
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2227.1 Safari/537.36",
    "Mozilla/5.0 (Windows NT 6.2; rv:21.0) Gecko/20130326 Firefox/21.0",
    "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/29.0.1547.2 Safari/537.36",
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10; rv:33.0) Gecko/20100101 Firefox/33.0",
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2227.1 Safari/537.36",
    "Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2049.0 Safari/537.36",
    "Mozilla/5.0 (X11; Linux x86_64; rv:28.0) Gecko/20100101  Firefox/28.0",
    "Mozilla/5.0 (Windows NT 6.1; WOW64; rv:29.0) Gecko/20120101 Firefox/29.0",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/29.0.1547.62 Safari/537.36",
    "Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1667.0 Safari/537.36",
    "Mozilla/5.0 (Windows NT 6.1; rv:21.0) Gecko/20130401 Firefox/21.0",
    "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.67 Safari/537.36",
    "Mozilla/5.0 (Windows x86; rv:19.0) Gecko/20100101 Firefox/19.0",
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_2) AppleWebKit/537.17 (KHTML, like Gecko) Chrome/24.0.1309.0 Safari/537.17",
    "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2225.0 Safari/537.36",
    "Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1667.0 Safari/537.36",
    "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.0 Safari/605.1.15"]

# %% [markdown]
# #### （3）小程序做好准备

# %%
def random_HEAD():  #得到一个随机登录系统的字典
    head = {}
    ua = random.choice(ualist)  #模拟随机登录系统
    head["User-Agent"] = ua
    return head

# %%
def hahaURL(url, head): #获取网页的html
    response = requests.get(url=url, headers=head)
    html = response.text
    return html

# %%
def hahaLI(html): #获取所有li的标签，这里对每个网页提取分图片链接的时候使用
    soup = BeautifulSoup(html, 'html.parser')
    allli = soup.find_all('li')
    return allli

# %%
def wuhuDIV(html): #获取所有div标签
    soup = BeautifulSoup(html, 'html.parser')
    all_links = soup.find_all('div', class_='photo-pic')
    return all_links

# %% [markdown]
# #### （4）主函数

# %%
def main(nn): #修改中
    """
    nn表示获取5次
    """
    m = 20  #图片标号起始值，自己定义
    method1 = re.compile(r'"(.*?\d+.html)"') #正则表达式，获取单张图片网页
    method2 = re.compile(r'src="(.*?)"')

    for i in range(1, nn+1):    ##############46-》5
        print(f"总共输出{nn}次，这是第{i}次",end="")
        ### index.html  index_2.html
        if i == 1:
            index = "index.html"
        else:
            index = f"index_{i}.html"
        url = baseurl+index
        head = random_HEAD()
        html = hahaURL(url, head)
        allli = hahaLI(html)
        for item in allli:
            if re.findall(method1, str(item)):
                url = 'http://pic.netbian.com' + \
                    re.findall(method1, str(item))[0]
                head = random_HEAD()
                html = hahaURL(url, head)
                all_links = wuhuDIV(html)
                for item in all_links:
                    m += 1
                    imgurl = 'http://pic.netbian.com' + \
                        re.findall(method2, str(item))[0]  # 获取大图片链接
                    head = random_HEAD()
                    wuhu = requests.get(url=imgurl, headers=head)
                    # 图片存储位置，不同系统的电脑写法不一样
                    where = r'web_spider/pic/fj%d.jpg' % (m)#这个m在main函数开头定义了
                    f = open(where, 'wb')
                    f.write(wuhu.content)
                    time.sleep(3)#每下载一张图片等3秒，当然为了速度你也不用要这一行
                    print(".",end="")
        print("\r",end="")
    print("全部图片抓取任务结束！！！！")

# %% [markdown]
# #### （5）调用

# %%
main(2)
